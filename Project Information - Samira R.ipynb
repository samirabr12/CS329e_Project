# %% [markdown]
# # CS 329e Term Project - Samira Ravilisetty (Fall 2021)

# %% [markdown]
# ## The Dataset - Health

# %%
import pandas as pd
project_dataset = pd.read_csv('Heart.csv')
project_dataset
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal Target
# 0        2.3      3  0.0       fixed     No
# ...

# %% [markdown]
# ### What is your data set about?

# %% [markdown]
# The dataset is a health dataset about various patients, mainly if they have heart disease or not. The features in the dataset include age, sex, fasting blood sugar, maximum heart rate, number of major vessels, and more. The dataset has different types of data, such as quantitative/numerical and categorical/qualitative.

# %% [markdown]
# ### What is exactly your research question? What do you want to learn from data? What is your learning model ,e.g., a Classification, Clustering, etc?

# %% [markdown]
# The research question is if I can predict if a patient has a heart disease or not using the various features in the dataset and using different machine learning models. The main model I will be using is a Support Vector Machine (SVM). I would like to learn which features most affect/are associated with the target variable, and how we can utilize those features to make accurate predictions of the target variable.

# %% [markdown]
# ### What is your current expectation about the results?

# %% [markdown]
# Currently, I am expecting that I will be able to predict the target variable accurately. Specifically, I am expecting that we will learn how heart disease is related to other aspects of health, such as age, sex or number of major vessels. However, I am predicting that it will be difficult to perform or that the accuracy score will be low and that the model will have to improve. The data is relatively small so the results might vary.

# %% [markdown]
# ### How do you want to evaluate your project? How to access the correctness of your model? How well would you expect that the model will work?

# %% [markdown]
# To evaluate the accuracy of my project/model I will be using various accuracy metrics. For Support Vector Machine I will be calculating accuracy, recall, precision and F1-score, as well as the correlation between each variable. . I am expecting the models to have an accuracy score of at least 0.6.
