# %% [markdown]
# # CS 329e Term Project - Samira Ravilisetty (Fall 2021)

# %% [markdown]
# ## The Dataset - Melbourne Housing

# %%
import pandas as pd
project_dataset = pd.read_csv('melb_data.csv')
project_dataset
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %% [markdown]
# ### What is your data set about?

# %% [markdown]
# The dataset is about Melbourne Housing and the statistics/data for each suburb and region. The features include items such as number of rooms, cars, and bathrooms and details such as price, year built, landsize, and more. The dataset includes different types of housing, from different areas of Melbourne. The data has different data types, such as string, date, and integer types.

# %% [markdown]
# ### What is exactly your research question? What do you want to learn from data? What is your learning model ,e.g., a Classification, Clustering, etc?

# %% [markdown]
# The research question is if one is able to predict the price of a housing unit in Melbourne according to the different features and details about each unit in the dataset. Using various learning models such as linear regression and logistic regression, classification methods such as Support Vector Machines, and clustering methods such as K-Nearest Neighbors.

# %% [markdown]
# ### What is your current expectation about the results?

# %% [markdown]
# Currently, I am expecting that I will be able to predict the price of a housing unit in Melbourne using various models. Specifically, I am expecting that price is significantly different for each Region/Suburb (geographically) or that it might vary according to the property details itself such as number of bathrooms, bedrooms, and more. However, I am predicting that it will be difficult to perform some of the models such as classification and clustering due to the fact the data might be somewhat similar/not varying after narrowing the dataset down from 13,000 observations to 2,000.

# %% [markdown]
# ### How do you want to evaluate your project? How to access the correctness of your model? How well would you expect that the model will work?

# %% [markdown]
# To evaluate the accuracy of my project/models I will be using various accuracy metrics. For regression models specifically I will be calculating metrics such as recall, accuracy, precision and F1-score. In addition, I will be calculating the R-squared score to see how well the model is performing. For Support Vector Machine I will be evaluating the correctness by seeing if the cost is decreasing after each iteration. For K-Nearest Neighbor, I will see if the accuracy score is increasing after each iteration. I am expecting the models to have an accuracy score of at least 0.7 and/or to have a decreasing cost that reaches zero.
